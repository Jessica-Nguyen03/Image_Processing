# %% [markdown]
# ## Basic

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# %%
retval = cv2.imread("D:\Image_Processing\hinh dep.jpg")
plt.imshow(retval)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\nguye\AppData\Local\Temp\ipykernel_15452\3513715222.py:1: SyntaxWarning: invalid escape sequence '\I'
#   retval = cv2.imread("D:\Image_Processing\hinh dep.jpg")

# %%
cv2.imshow("Test img",retval)
cv2.waitKey(0)
cv2.namedWindow()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 cv2.imshow("Test img",retval)
#       2 cv2.waitKey(0)
# ----> 3 cv2.namedWindow()
#
# TypeError: namedWindow() missing required argument 'winname' (pos 1)

# %% [markdown]
# ## Binary and Grayscale img

# %%
retval.shape
# Out:
# (158, 168, 3)

# %%
b,g,r = cv2.split(retval)
imgMerge = cv2.merge((b, g, r))
plt.figure()

plt.subplot(141);plt.imshow(b,cmap='gray');plt.title("Blue channel")
plt.subplot(142);plt.imshow(g,cmap='gray');plt.title("Green channel")
plt.subplot(143);plt.imshow(r,cmap='gray');plt.title("Red channel")
plt.subplot(144);plt.imshow(imgMerge[:,:,::-1]);plt.title("Merged Output")
# Out:
# Text(0.5, 1.0, 'Merged Output')
