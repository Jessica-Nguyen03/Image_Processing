# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# %%
retval = cv2.imread("D:\Image_Processing\hinh dep.jpg",0)
plt.imshow(retval)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\nguye\AppData\Local\Temp\ipykernel_23056\2047232823.py:1: SyntaxWarning: invalid escape sequence '\I'
#   retval = cv2.imread("D:\Image_Processing\hinh dep.jpg",0)
